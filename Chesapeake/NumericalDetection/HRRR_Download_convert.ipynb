# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
from mmctools.wrf.preprocessing import ERA5
import sys
import xarray as xr
import pygrib
import glob
import requests
import os
import matplotlib.pyplot as plt

# %% [markdown]
# # Download the file:

# %%
def download_HRRR(datetime,save_dir,forecast_hr=None):
    if forecast_hr is None:
        url = 'https://pando-rgw01.chpc.utah.edu/hrrr/sfc/{0:04d}{1:02d}{2:02d}/hrrr.t{3:02d}z.wrfsfcf00.grib2'.format(
                                                                datetime.year,datetime.month,datetime.day,datetime.hour)
        new_f_name = 'hrrr.{0:04d}{1:02d}{2:02d}.t{3:02d}z.wrfsfcf00.grib2'.format(
                        datetime.year,datetime.month,datetime.day,datetime.hour)
    else:
        url = 'https://pando-rgw01.chpc.utah.edu/hrrr/sfc/{0:04d}{1:02d}{2:02d}/hrrr.t{3:02d}z.wrfsfcf{4:02d}.grib2'.format(
                                                                datetime.year,datetime.month,datetime.day,datetime.hour,forecast_hr)
        new_f_name = 'hrrr.{0:04d}{1:02d}{2:02d}.t{3:02d}z.wrfsfcf{4:02d}.grib2'.format(
                        datetime.year,datetime.month,datetime.day,datetime.hour,forecast_hr)
        

    
    if os.path.exists('{}{}'.format(save_dir,new_f_name)):
        print('{}{} already downloaded.'.format(save_dir,new_f_name))
    else:
        r = requests.get(url, allow_redirects=True)
        #new_f_name = 'hrrr.{0:04d}{1:02d}{2:02d}.t{3:02d}z.wrfsfcf00.grib2'.format(
        #                datetime.year,datetime.month,datetime.day,datetime.hour)
        open('{}{}'.format(save_dir,new_f_name), 'wb').write(r.content)
    return(new_f_name)

# %% [markdown]
# # Convert the file with NCL script:

# %%
def convert_GRIB2_NetCDF(grib_dir,grib_name,
                         ncl_loc='/Users/hawbecke/.conda/envs/ncl_stable/bin/ncl',
                         run_script=True):
    
    aux_cmd = 'fname="{}"'.format(grib_name.replace('.grib2',''))
    scrpt_n = 'grib2netcdf.ncl'
    arg_str = 'cd {} && '.format(grib_dir) + ncl_loc + " '"+aux_cmd+"' " + scrpt_n #+ ' && cd -'
    if run_script:
        os.system(arg_str)
    else:
        print(arg_str)
    
    new_f_name = grib_name.replace('grib2','nc')
    return(new_f_name)

# %% [markdown]
# # Truncate NetCDF to only MD area:

# %%
def crop_NetCDF(fname,xs,ys,span):
    ncd = xr.open_dataset(fname)
    ncd_small = ncd.sel(xgrid_0=slice(xs,xs+span),ygrid_0=slice(ys,ys+span))

    # Moved the variable extraction into the NCL code...
    '''
    good_vars = ['LAND_P0_L1_GLC0',
                 'HGT_P0_L1_GLC0',
                 'gridlat_0',
                 'gridlon_0',
                 'TMP_P0_L103_GLC0',
                 'POT_P0_L103_GLC0',
                 'UGRD_P0_L103_GLC0',
                 'VGRD_P0_L103_GLC0',
                 'PRES_P0_L1_GLC0',
                 'HGT_P0_L100_GLC0',
                 'TMP_P0_L100_GLC0',
                 'POT_P0_L103_GLC0',
                 'UGRD_P0_L100_GLC0',
                 'VGRD_P0_L100_GLC0',
                 'lv_HTGL2',
                 'lv_ISBL0',
                 'lv_ISBL1',
                 'lv_ISBL5',
                ]
    for varn in ncd_small.variables:
        if varn not in good_vars:
            ncd_small = ncd_small.drop(varn)
    '''
    
    os.system('rm {}'.format(fname))
    ncd_small.to_netcdf('{}'.format(fname))
    
    return(ncd_small)

# %% [markdown]
# # Loop over days and hours:

# %%
hrrr_dir = '/Users/hawbecke/Research/Chesapeake/Data/HRRR/forecast/'
xs = 1400
ys = 500
span = 201
h_s, h_e = 13,22

hrrr_type = 'forecast'

if hrrr_type == 'analysis':
    date_range = pd.date_range('2019-07-16 {0:02d}:00:00'.format(h_s),
                               '2019-07-31 {0:02d}:00:00'.format(h_e),freq='1h')
elif hrrr_type == 'forecast':
    forecast_s = 10
    forecast_hrs = range(0,19)
    date_range = pd.date_range('2019-07-16 {0:02d}:00:00'.format(forecast_s),
                               '2019-07-31 {0:02d}:00:00'.format(forecast_s),freq='1d')

# %%
def write_grib2ncdf_code(grib_dir):
    if 'forecast' in grib_dir:
        precip_var = 'APCP_P8_L1_GLC0_acc1h'
    else:
        precip_var = 'APCP_P8_L1_GLC0_acc'
        
    ncl_file = open('{}grib2netcdf.ncl'.format(grib_dir),'w')
    ncl_file.write('begin\n')
    ncl_file.write(';***********************************************\n')
    ncl_file.write('; get variable names from grib file\n')
    ncl_file.write(';***********************************************\n')
    ncl_file.write(';    fname    = "hrrr.t15z.wrfsfcf00"\n')
    ncl_file.write('    grib_in  = addfile("./"+fname+".grib2","r")\n')
    ncl_file.write(';    names    = getfilevarnames(grib_in); extract all variable names\n')
    ncl_file.write('    names = (/"LAND_P0_L1_GLC0","HGT_P0_L1_GLC0","gridlat_0","gridlon_0","TMP_P0_L103_GLC0","POT_P0_L103_GLC0","UGRD_P0_L103_GLC0","VGRD_P0_L103_GLC0","PRES_P0_L1_GLC0","HGT_P0_L100_GLC0","TMP_P0_L100_GLC0","POT_P0_L103_GLC0","UGRD_P0_L100_GLC0","VGRD_P0_L100_GLC0","lv_HTGL2","lv_ISBL0","lv_ISBL1","lv_ISBL5","LCDC_P0_L214_GLC0","TCDC_P0_L10_GLC0","MCDC_P0_L224_GLC0","HCDC_P0_L234_GLC0","{}"/)\n'.format(precip_var))
    ncl_file.write('    ;***********************************************\n')
    ncl_file.write('    ; create output netcdf file\n')
    ncl_file.write('    ;***********************************************\n')
    ncl_file.write('    system("rm " + fname + ".nc") ; remove any pre-existing file\n')
    ncl_file.write('    ncdf_out = addfile(fname + ".nc" ,"c")       ; create output netCDF file\n')
    ncl_file.write('    ;***********************************************\n')
    ncl_file.write('    ; loop through variables and output each to netcdf\n')
    ncl_file.write('    ;***********************************************\n')
    ncl_file.write('    do i = 0, dimsizes(names)-1\n')
    ncl_file.write('        ncdf_out->$names(i)$ = grib_in->$names(i)$\n')
    ncl_file.write('    end do\n')
    ncl_file.write('end\n')
    ncl_file.close()

# %%
write_grib2ncdf_code(hrrr_dir)
for dd,date in enumerate(date_range):
    if hrrr_type == 'analysis':
        if (date.hour >= h_s) & (date.hour <= h_e):
            print(date)
            grib_n = download_HRRR(date,hrrr_dir)
            hrrr_fname = convert_GRIB2_NetCDF(hrrr_dir,grib_n)
            new_nc = crop_NetCDF('{}{}'.format(hrrr_dir,hrrr_fname),xs,ys,span)
    elif hrrr_type == 'forecast':
        for forecast_hr in forecast_hrs:
            hr = (date + pd.to_timedelta(forecast_hr,'h')).hour
            if (hr >= h_s) & (hr <= h_e):
                print('{} - forecast hour: {}\t hour: {}'.format(date,forecast_hr,hr))

                grib_n = download_HRRR(date,hrrr_dir,forecast_hr=forecast_hr)
                hrrr_fname = convert_GRIB2_NetCDF(hrrr_dir,grib_n)
                new_nc = crop_NetCDF('{}{}'.format(hrrr_dir,hrrr_fname),xs,ys,span)
# Out:
# 2019-07-16 10:00:00 - forecast hour: 3	 hour: 13
# 2019-07-16 10:00:00 - forecast hour: 4	 hour: 14
# 2019-07-16 10:00:00 - forecast hour: 5	 hour: 15
# 2019-07-16 10:00:00 - forecast hour: 6	 hour: 16
# 2019-07-16 10:00:00 - forecast hour: 7	 hour: 17
# 2019-07-16 10:00:00 - forecast hour: 8	 hour: 18
# 2019-07-16 10:00:00 - forecast hour: 9	 hour: 19
# 2019-07-16 10:00:00 - forecast hour: 10	 hour: 20
# 2019-07-16 10:00:00 - forecast hour: 11	 hour: 21
# 2019-07-16 10:00:00 - forecast hour: 12	 hour: 22
# 2019-07-17 10:00:00 - forecast hour: 3	 hour: 13
# 2019-07-17 10:00:00 - forecast hour: 4	 hour: 14
# 2019-07-17 10:00:00 - forecast hour: 5	 hour: 15
# 2019-07-17 10:00:00 - forecast hour: 6	 hour: 16
# 2019-07-17 10:00:00 - forecast hour: 7	 hour: 17
# 2019-07-17 10:00:00 - forecast hour: 8	 hour: 18
# 2019-07-17 10:00:00 - forecast hour: 9	 hour: 19
# 2019-07-17 10:00:00 - forecast hour: 10	 hour: 20
# 2019-07-17 10:00:00 - forecast hour: 11	 hour: 21
# ...

# %% [markdown]
# ### If you want to add more variables:

# %% [raw]
#    HRRR Variable                       Long Name
# TMP_P0_L1_GLC0                 Temperature
# TMP_P0_L100_GLC0               Temperature
# TMP_P0_L103_GLC0               Temperature
# POT_P0_L103_GLC0               Potential temperature
# DPT_P0_L100_GLC0               Dew point temperature
# DPT_P0_L103_GLC0               Dew point temperature
# LHTFL_P0_L1_GLC0               Latent heat net flux
# SHTFL_P0_L1_GLC0               Sensible heat net flux
# SPFH_P0_L103_GLC0              Specific humidity
# RH_P0_L4_GLC0                  Relative humidity
# RH_P0_L103_GLC0                Relative humidity
# RH_P0_L204_GLC0                Relative humidity
# PWAT_P0_L200_GLC0              Precipitable water
# PRATE_P0_L1_GLC0               Precipitation rate
# SNOD_P0_L1_GLC0                Snow depth
# WEASD_P0_L1_GLC0               Water equivalent of accumulated snow depth
# CRAIN_P0_L1_GLC0               Categorical rain
# CFRZR_P0_L1_GLC0               Categorical freezing rain
# CICEP_P0_L1_GLC0               Categorical ice pellets
# CSNOW_P0_L1_GLC0               Categorical snow
# CPOFP_P0_L1_GLC0               Percent frozen precipitation
# SNOWC_P0_L1_GLC0               Snow cover
# RHPW_P0_L10_GLC0               Relative humidity with respect to precipitable water
# UGRD_P0_L100_GLC0              U-component of wind
# UGRD_P0_L103_GLC0              U-component of wind
# VGRD_P0_L100_GLC0              V-component of wind
# VGRD_P0_L103_GLC0              V-component of wind
# VUCSH_P0_2L103_GLC0            Vertical u-component of shear
# VVCSH_P0_2L103_GLC0            Vertical v-component of shear
# GUST_P0_L1_GLC0                Wind speed (gust)
# USTM_P0_2L103_GLC0             U-component storm motion
# VSTM_P0_2L103_GLC0             V-component storm motion
# FRICV_P0_L1_GLC0               Frictional velocity
# PRES_P0_L1_GLC0                Pressure
# PRES_P0_L2_GLC0                Pressure
# PRES_P0_L3_GLC0                Pressure
# PRES_P0_L4_GLC0                Pressure
# PRES_P0_L204_GLC0              Pressure
# HGT_P0_L1_GLC0                 Geopotential height
# HGT_P0_L2_GLC0                 Geopotential height
# HGT_P0_L3_GLC0                 Geopotential height
# HGT_P0_L4_GLC0                 Geopotential height
# HGT_P0_L5_GLC0                 Geopotential height
# HGT_P0_L20_GLC0                Geopotential height
# HGT_P0_L100_GLC0               Geopotential height
# HGT_P0_L204_GLC0               Geopotential height
# HGT_P0_L215_GLC0               Geopotential height
# HGT_P0_L247_GLC0               Geopotential height
# HPBL_P0_L1_GLC0                Planetary boundary layer height
# MSLMA_P0_L101_GLC0             MSLP (MAPS system reduction)
# PLPL_P0_2L108_GLC0             Pressure of level from which parcel was lifted
# DSWRF_P0_L1_GLC0               Downward short-wave radiation flux
# USWRF_P0_L1_GLC0               Upward short-wave radiation flux
# USWRF_P0_L8_GLC0               Upward short-wave radiation flux
# VBDSF_P0_L1_GLC0               Visible beam downward solar flux
# VDDSF_P0_L1_GLC0               Visible diffuse downward solar flux
# DLWRF_P0_L1_GLC0               Downward long-wave rad. flux
# ULWRF_P0_L1_GLC0               Upward long-wave rad. flux
# ULWRF_P0_L8_GLC0               Upward long-wave rad. flux
# TCDC_P0_L10_GLC0               Total cloud cover
# LCDC_P0_L214_GLC0              Low cloud cover
# MCDC_P0_L224_GLC0              Medium cloud cover
# HCDC_P0_L234_GLC0              High cloud cover
# CAPE_P0_L1_GLC0                Convective available potential energy
# CAPE_P0_2L108_GLC0             Convective available potential energy
# CIN_P0_L1_GLC0                 Convective inhibition
# CIN_P0_2L108_GLC0              Convective inhibition
# HLCY_P0_2L103_GLC0             Storm relative helicity
# LFTX_P0_2L100_GLC0             Surface lifted index
# 4LFTX_P0_2L108_GLC0            Best (4 layer) lifted index
# VIL_P0_L10_GLC0                Vertically-integrated liquid water
# RETOP_P0_L3_GLC0               Echo top
# REFD_P0_L20_GLC0               Reflectivity
# REFD_P0_L103_GLC0              Reflectivity
# REFC_P0_L10_GLC0               Composite reflectivity
# LTNG_P0_L10_GLC0               Lightning
# VIS_P0_L1_GLC0                 Visibility
# LAND_P0_L1_GLC0                Land cover (1=land, 0=sea)
# SFCR_P0_L1_GLC0                Surface roughness
# GFLUX_P0_L1_GLC0               Ground heat flux
# CNWAT_P0_L1_GLC0               Plant canopy surface water
# MSTAV_P0_L106_GLC0             Moisture availability
# VGTYP_P0_L1_GLC0               Vegetation type
# SBT123_P0_L8_GLC0              Simulated brightness temperature for GOES 12, channel 3
# SBT124_P0_L8_GLC0              Simulated brightness temperature for GOES 12, channel 4
# SBT113_P0_L8_GLC0              Simulated brightness temperature for GOES 11, channel 3
# SBT114_P0_L8_GLC0              Simulated brightness temperature for GOES 11, channel 4
# ICEC_P0_L1_GLC0                Ice cover
# APCP_P8_L1_GLC0_acc            Total precipitation
# WEASD_P8_L1_GLC0_acc           Water equivalent of accumulated snow depth
# ASNOW_P8_L1_GLC0_acc           Total snowfall
# HAIL_P8_L10_GLC0_max           Hail
# HAIL_P8_L104_GLC0_max          Hail
# TCOLG_P8_L200_GLC0_max         Total column integrated graupel
# FRZR_P8_L1_GLC0_acc            Freezing rain
# FROZR_P8_L1_GLC0_acc           Frozen rain
# WIND_P8_L103_GLC0_max          Wind speed
# DZDT_P8_2L104_GLC0_avg         Vertical velocity (geometric)
# RELV_P8_2L103_GLC0_max         Relative vorticity
# MAXUVV_P8_2L108_GLC0_max       Hourly maximum of upward vertical velocity in the lowest 400hPa
# MAXDVV_P8_2L108_GLC0_max       Hourly maximum of downward vertical velocity in the lowest 400hPa
# MAXUW_P8_L103_GLC0_max         U component of hourly maximum 10m wind speed
# MAXVW_P8_L103_GLC0_max         V component of hourly maximum 10m wind speed
# MXUPHL_P8_2L103_GLC0_max       Hourly maximum of updraft helicity over layer 2km to 5 km AGL
# VAR_0_7_200_P8_2L103_GLC0_min  unknown variable name
# REFD_P8_L20_GLC0_max           Reflectivity
# MAXREF_P8_L103_GLC0_max        Hourly maximum of simulated reflectivity at 1 km AGL
# BGRUN_P8_L1_GLC0_acc           Baseflow-groundwater runoff
# SSRUN_P8_L1_GLC0_acc           Storm surface runoff
# lv_HTGL10_l1                   Specified height level above ground
# lv_HTGL10_l0                   Specified height level above ground
# lv_HTGL9_l1                    Specified height level above ground
# lv_HTGL9_l0                    Specified height level above ground
# lv_HTGL7_l1                    Specified height level above ground
# lv_HTGL7_l0                    Specified height level above ground
# lv_SPDL6_l1                    Level at specified pressure difference from ground to level
# lv_SPDL6_l0                    Level at specified pressure difference from ground to level
# lv_HTGL3_l1                    Specified height level above ground
# lv_HTGL3_l0                    Specified height level above ground
# gridrot_0                      vector rotation angle
